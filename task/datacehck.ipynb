# %%
import pandas as pd

# %%
data1=pd.read_csv("dataset/data1.csv")

df1=pd.DataFrame(data1)


print(df1)
# Out:
#                                                      text  generated
# 0       Cars. Cars have been around since they became ...        0.0
# 1       Transportation is a large necessity in most co...        0.0
# 2       "America's love affair with it's vehicles seem...        0.0
# 3       How often do you ride in a car? Do you drive a...        0.0
# 4       Cars are a wonderful thing. They are perhaps o...        0.0
# ...                                                   ...        ...
# 487230  Tie Face on Mars is really just a big misunder...        0.0
# 487231  The whole purpose of democracy is to create a ...        0.0
# 487232  I firmly believe that governments worldwide sh...        1.0
# 487233  I DFN't agree with this decision because a LFT...        0.0
# 487234  Richard Non, Jimmy Carter, and Bob Dole and ot...        0.0
#
# [487235 rows x 2 columns]

# %%
data2=pd.read_csv("dataset/data2.csv")
df2=pd.DataFrame(data2)

print(df2.to_string)
# Out:
# <bound method DataFrame.to_string of                                                      text  label  word_count
# 0       Hey there! For this essay, I had to research d...      1         352
# 1       You've been at school all day ready to go to w...      0         445
# 2       I disagree with the principal making all stude...      0         308
# 3       In the passage "The Challenge of Exploring Ven...      0         289
# 4       Theirs many Other ways to go from One place to...      0         616
# ...                                                   ...    ...         ...
# 437259  To create an essay on the Face on Mars topic, ...      1         647
# 437260  Deal Principal, I am writing to you today to e...      1         252
# 437261  Some schools require students to complete summ...      0         344
# 437262  It was a normal day at the lunchroom when I no...      0         650
# 437263  Some schools offer distance leaving as av opti...      0         572
#
# [437264 rows x 3 columns]>
